# %% [markdown]
# # Explanatory Data Analysis, Basic Plots

# %% [markdown]
# This script visualizes many plots from the Weather, Vehicle and Airquality Data. All of the dataframes are saved in: processed_data. There are multiple scales we are looking at. We are working with hourly, daily and yearly data. This script is also organized in this order.

# %%
# import packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
from matplotlib import style

# %% [markdown]
# # Dataframe: Full data imputed (hourly)

# %%
# read data (full data imputed) with correct date format

date = lambda x: pd.datetime.strptime(x, "%Y-%m-%dT%H:%M")
df = pd.read_csv('/Users/alisha/Documents/UZH_FS2022/ESC403_IDS/IDS_Project_working_directory/data_science_project/processed_data/full_data_imputed_with_EAQI.csv', parse_dates = ["Datum"], date_parser = date)

df.info()
df.describe()
# Out:
# /var/folders/_6/_h0d2w315356l929c_mc_ntc0000gn/T/ipykernel_766/3767958950.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   date = lambda x: pd.datetime.strptime(x, "%Y-%m-%dT%H:%M")
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128443 entries, 0 to 128442
# Data columns (total 25 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Jahr           128443 non-null  int64
#  1   Monat          128443 non-null  int64
#  2   Tag            128443 non-null  int64
#  3   Zeit           128443 non-null  object
#  4   Datum          128443 non-null  datetime64[ns]
#  5   Zweirad        128443 non-null  int64
#  6   Personenwagen  128443 non-null  int64
#  7   Lastwagen      128443 non-null  int64
#  8   Hr             128443 non-null  float64
#  9   RainDur        128443 non-null  float64
#  10  T              128443 non-null  float64
#  11  WVs            128443 non-null  float64
#  12  StrGlo         128443 non-null  float64
#  13  p              128443 non-null  float64
#  14  NO2            128443 non-null  float64
#  15  NO             128443 non-null  float64
#  16  NOx            128443 non-null  float64
#  17  O3             128443 non-null  float64
#  18  CO             128443 non-null  float64
#  19  PM10           128443 non-null  float64
#  20  SO2            128443 non-null  float64
#  21  PM10_calc      128426 non-null  float64
#  22  NO2_AQI        128443 non-null  int64
#  23  PM10_AQI       128416 non-null  float64
#  24  AQI            128443 non-null  float64
# dtypes: datetime64[ns](1), float64(16), int64(7), object(1)
# memory usage: 24.5+ MB
#                 Jahr          Monat            Tag        Zweirad  \
# count  128443.000000  128443.000000  128443.000000  128443.000000
# mean     2014.103081       6.534315      15.730487      39.139579
# std         4.291773       3.451984       8.793820      33.079361
# min      2007.000000       1.000000       1.000000       0.000000
# 25%      2010.000000       4.000000       8.000000      13.000000
# 50%      2014.000000       7.000000      16.000000      32.000000
# 75%      2018.000000      10.000000      23.000000      57.000000
# max      2021.000000      12.000000      31.000000     275.000000
#
#        Personenwagen      Lastwagen             Hr        RainDur  \
# count  128443.000000  128443.000000  128443.000000  128443.000000
# mean      246.242473       8.482798      69.674314       6.083562
# std       155.746475       8.138571      16.760255      15.387678
# min         0.000000       0.000000      14.110000       0.000000
# 25%       123.000000       2.000000      58.480000       0.000000
# 50%       231.000000       6.000000      73.020000       0.000000
# 75%       351.000000      12.000000      83.320000       0.000000
# max      1866.000000     210.000000     105.919000      60.000000
#
#                    T            WVs  ...             NO            NOx  \
# count  128443.000000  128443.000000  ...  128443.000000  128443.000000
# mean       11.684707       1.742269  ...      17.061260      30.174128
# std         7.945038       1.044402  ...      26.389498      29.153317
# min       -13.250000       0.000000  ...      -0.690000       0.650000
# 25%         5.410000       1.000000  ...       2.870000      11.180000
# 50%        11.430000       1.570000  ...       7.200000      20.860000
# 75%        17.620000       2.240000  ...      19.240000      38.720000
# max        36.676000      11.710000  ...     496.700000     437.960000
#
#                   O3             CO           PM10            SO2  \
# count  128443.000000  128443.000000  128443.000000  128443.000000
# mean       44.274205       0.351945      18.908141       1.940779
# std        31.756340       0.185195      13.822406       1.813317
# min        -0.840000       0.040000    -267.300000      -0.180000
# 25%        16.340000       0.230000      10.160000       1.010000
# 50%        42.950000       0.300000      16.010000       1.420000
# 75%        65.525000       0.420000      24.080000       2.200000
# max       180.220000       4.100000     593.440000      67.230000
#
#            PM10_calc        NO2_AQI       PM10_AQI            AQI
# count  128426.000000  128443.000000  128416.000000  128443.000000
# mean       18.908731       0.302064       0.427704       0.555032
# std        11.156819       0.477638       0.662880       0.671695
# min        -2.025000       0.000000       0.000000       0.000000
# 25%        11.259000       0.000000       0.000000       0.000000
# 50%        16.322000       0.000000       0.000000       0.000000
# 75%        23.391000       1.000000       1.000000       1.000000
# max        97.057000       4.000000       3.000000       4.000000
#
# [8 rows x 23 columns]

# %% [markdown]
# Comment:
# The date was in a "object" format, so I corrected it with the datetime format. This dataset shows hourly data.

# %%
# create dataframe with data from January 2021

df_2021 = df[df.Jahr == 2021]
df_2021_mean = df_2021.mean()

df_2021_jan = df_2021[df_2021.Monat == 1]
df_2021_jan.mean()
# Out:
# /var/folders/_6/_h0d2w315356l929c_mc_ntc0000gn/T/ipykernel_766/205526607.py:4: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df_2021_mean = df_2021.mean()
# /var/folders/_6/_h0d2w315356l929c_mc_ntc0000gn/T/ipykernel_766/205526607.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_2021_mean = df_2021.mean()
# /var/folders/_6/_h0d2w315356l929c_mc_ntc0000gn/T/ipykernel_766/205526607.py:7: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df_2021_jan.mean()
# /var/folders/_6/_h0d2w315356l929c_mc_ntc0000gn/T/ipykernel_766/205526607.py:7: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_2021_jan.mean()
# Jahr             2021.000000
# Monat               1.000000
# Tag                16.010796
# Zweirad            31.295547
# Personenwagen     126.446694
# Lastwagen           3.298246
# Hr                 79.327692
# RainDur            11.409784
# T                   2.004278
# WVs                 2.179636
# StrGlo             34.658205
# p                 961.359028
# NO2                26.730383
# NO                  9.403551
# NOx                21.517320
# O3                 35.851606
# CO                  0.223776
# PM10               14.328219
# SO2                 1.299035
# PM10_calc          14.396553
# NO2_AQI             0.187584
# PM10_AQI            0.263158
# AQI                 0.422402
# dtype: float64

# %% [markdown]
# ### HOURLY: Vehicle counts January 2021

# %%
# Plot trucks, hourly data from January 2021

plt.figure(figsize = (20,4))

plt.plot(df_2021_jan["Datum"], df_2021_jan["Lastwagen"], "r.-", label = "Trucks", lw = 0.8)


plt.title("Trucks January 2021")
plt.ylabel("Trucks counts")
plt.xlabel("January 2021 dates")
plt.legend()


plt.show()

# %%
# Plot cars, hourly data from January 2021

plt.figure(figsize = (20,4))

plt.plot(df_2021_jan["Datum"], df_2021_jan["Personenwagen"], "b.-", label = "Personenwagen", lw = 0.8)


plt.title("Cars 2007 to 2021")
plt.ylabel("Cars counts")
plt.xlabel("January 2021 dates")
plt.legend()


plt.show()

# %%
# Plot bicycles and Rain Duration January 2021

fig, ax1 = plt.subplots(figsize = (12,8))

plt.title("Bicycles and Rain Duration January 2021")
plt.xlabel("January 2021 dates")

ax1.plot(df_2021_jan["Datum"], df_2021_jan["Zweirad"], "g.-", label = "Bicycles", lw = 0.3)

ax2 = ax1.twinx()
ax2.plot(df_2021_jan["Datum"], df_2021_jan["RainDur"], "b.")

ax1.set_ylabel("Bicycle count")
ax2.set_ylabel("Rain Duration")


plt.show()

# %%
# Plot bicycles and Temperature January 2021

fig, ax1 = plt.subplots(figsize = (12,8))

plt.xlabel("January 2021 dates")
plt.title("Bicycles and Temperature January 2021")

ax1.plot(df_2021_jan["Datum"], df_2021_jan["Zweirad"], "g.-", label = "Bicycles", lw = 0.3)

ax2 = ax1.twinx()
ax2.plot(df_2021_jan["Datum"], df_2021_jan["T"], color = "orange", lw = 0.9)

ax1.set_ylabel("Bicycle count")
ax2.set_ylabel("Temperature [°C]")


plt.show()

# %%
# Plot bicycles and Global Radiation January 2021

fig, ax1 = plt.subplots(figsize = (12,8))

plt.xlabel("January 2021 dates")
plt.title("Bicycles and Global Radiation January 2021")

ax1.plot(df_2021_jan["Datum"], df_2021_jan["Zweirad"], "g.-", label = "Bicycles", lw = 0.3)

ax2 = ax1.twinx()
ax2.plot(df_2021_jan["Datum"], df_2021_jan["StrGlo"], color = "red", lw = 0.9)

ax1.set_ylabel("Bicycle count")
ax2.set_ylabel("Global Radiation")


plt.show()

# %% [markdown]
# # Dataframe: Full data imputed daily

# %%
# read data with correct date format

date = lambda x: pd.datetime.strptime(x, "%Y-%m-%d")
daily = pd.read_csv('/Users/alisha/Documents/UZH_FS2022/ESC403_IDS/IDS_Project/data_science_project/processed_data/full_data_imputed_daily.csv', parse_dates = ["Tagesdatum"], date_parser = date)

daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5291 entries, 0 to 5290
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Jahr           5291 non-null   int64
#  1   Monat          5291 non-null   int64
#  2   Tag            5291 non-null   int64
#  3   Tagesdatum     5291 non-null   datetime64[ns]
#  4   Zweirad        5291 non-null   int64
#  5   Personenwagen  5291 non-null   int64
#  6   Lastwagen      5291 non-null   int64
#  7   Hr             5291 non-null   float64
#  8   RainDur        5291 non-null   float64
#  9   T              5291 non-null   float64
#  10  WVs            5291 non-null   float64
#  11  StrGlo         5291 non-null   float64
#  12  p              5291 non-null   float64
#  13  NO2            5291 non-null   float64
#  14  NO             5291 non-null   float64
#  15  NOx            5291 non-null   float64
#  16  O3             5291 non-null   float64
#  17  CO             5291 non-null   float64
#  18  PM10           5291 non-null   float64
#  19  SO2            5291 non-null   float64
# dtypes: datetime64[ns](1), float64(13), int64(6)
# memory usage: 826.8 KB
# /var/folders/_6/_h0d2w315356l929c_mc_ntc0000gn/T/ipykernel_766/3469336198.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   date = lambda x: pd.datetime.strptime(x, "%Y-%m-%d")

# %% [markdown]
# Comment: The date was in a "object" format, so I corrected it with the datetime format.

# %% [markdown]
# ### DAILY: Vehicle counts over the years

# %%
# daily cars, trucks and bycicles counts over the years


plt.figure(figsize = (20,11))


plt.plot(daily["Tagesdatum"], daily["Personenwagen"], "b.", label = "cars", lw = 0.3)
plt.plot(daily["Tagesdatum"], daily["Zweirad"], "g.", label = "bicycles", lw = 0.3)
plt.plot(daily["Tagesdatum"], daily["Lastwagen"], "r.", label = "trucks", lw = 0.3)


plt.title("Daily vehicle counts 2007 to 2021", fontsize = 32)
plt.ylabel("Vehicle counts", fontsize = 24)
plt.xlabel("years", fontsize = 24)
plt.legend(fontsize = 18)


plt.show()

# %%
# daily cars counts over the years


plt.figure(figsize = (20,11))


daily["ma_c"] = daily["Personenwagen"].rolling(window=60).mean()


plt.plot(daily["Tagesdatum"], daily["Personenwagen"], "b.", label = "cars", lw = 0.3)
plt.plot(daily["Tagesdatum"], daily["ma_c"], label = "cars moving average", lw = 4, color = "#909930")


plt.title("Daily cars counts 2007 to 2021", fontsize = 28)
plt.ylabel("Cars counts", fontsize = 24)
plt.xlabel("Years", fontsize = 24)
plt.legend()


plt.show()

# %%
# daily trucks counts over the years


plt.figure(figsize = (20,11))


daily["ma_t"] = daily["Lastwagen"].rolling(window=30).mean()

plt.plot(daily["Tagesdatum"], daily["Lastwagen"], "r.", label = "trucks", lw = 0.3)
plt.plot(daily["Tagesdatum"], daily["ma_t"], label = "trucks moving average", lw = 4, color = "#209090")


plt.title("Daily truck counts 2007 to 2021", fontsize = 30)
plt.ylabel("Truck counts", fontsize = 24)
plt.xlabel("Years", fontsize = 24)
plt.legend(fontsize = 18)


plt.show()

# %%
# daily bycicles counts over the years


plt.figure(figsize = (20,11))


daily["ma_b"] = daily["Zweirad"].rolling(window=30).mean()

plt.plot(daily["Tagesdatum"], daily["Zweirad"], "g.", label = "bicycles", lw = 0.3)
plt.plot(daily["Tagesdatum"], daily["ma_b"], label = "bicycles moving average", lw = 3, color = "black")


plt.title("Daily vehicle counts 2007 to 2021", fontsize = 28)
plt.ylabel("Vehicle counts", fontsize = 24)
plt.xlabel("years", fontsize = 24)
plt.legend(fontsize = 18)


plt.show()

# %% [markdown]
# Comment:
# Every day has a count with car, truck and bicycle counts. There are some values missing in 2008 and 2009.

# %% [markdown]
# ### DAILY: Vehicle counts troughout the months

# %%
# Trucks count in months of the year

plt.figure(figsize = (8,5))

plt.plot(daily["Monat"], daily["Lastwagen"], "r.", label = "Trucks")

plt.title("Trucks January to December")
plt.ylabel("Trucks count")
plt.xlabel("Months of the year")
plt.legend()

plt.show()

# %%
# Cars count in months of the year

plt.figure(figsize = (8,5))

plt.plot(daily["Monat"], daily["Personenwagen"], "b.", label = "Cars")

plt.title("Cars January to December")
plt.ylabel("Cars count")
plt.xlabel("Months of the year")
plt.legend()

plt.show()

# %%
# Bicycles count in months of the year

plt.figure(figsize = (8,5))

plt.plot(daily["Monat"], daily["Zweirad"], "g.", label = "Bicycles")

plt.title("Bicycle January to December")
plt.ylabel("Bycicles count")
plt.xlabel("Months of the year")
plt.legend()

plt.show()

# %% [markdown]
# ### DAILY: Airquality over the years

# %%
# airquality data over the years


plt.figure(figsize = (17, 10))


plt.plot(daily["Tagesdatum"], daily["PM10"], "o" , label = "PM10", color = "#208590")


plt.title("Daily PM10 values 2007 to 2021", fontsize = 20)
plt.ylabel("PM10 [µg/m³]", fontsize = 15)
plt.xlabel("Years", fontsize = 15)
plt.legend(fontsize = 15)


plt.show()

# %%
# airquality data over the years


plt.figure(figsize = (17, 10))


plt.plot(daily["Tagesdatum"], daily["NO2"], "o", label = "NO2", color = "#507099")


plt.title("Daily NO2 values 2007 to 2021", fontsize = 20)
plt.ylabel("NO2 [µg/m³]", fontsize = 15)
plt.xlabel("Years", fontsize = 15)
plt.legend(fontsize = 15)


plt.show()

# %% [markdown]
# ### DAILY: Weather samples

# %%
# daily rain duration


plt.figure(figsize = (20,4))

plt.plot(daily.Tagesdatum, daily.RainDur, "b.", label = "Rain Duration", lw = 0.2)

plt.title("Mean daily Rain Duration 2007 to 2021", fontsize = 16)
plt.ylabel("Rain Duration [?]", fontsize = 11)
plt.xlabel("Years", fontsize = 11)
plt.legend()


plt.show()

# %%
# daily relative humidity

plt.figure(figsize = (20,4))

plt.plot(daily.Tagesdatum, daily.Hr, "b.", label = "Relative Humidity", lw = 0.4)

plt.title("Mean daily Relative Humidity 2007 to 2021", fontsize = 16)
plt.ylabel("Relative Humidity [?]", fontsize = 11)
plt.xlabel("Years", fontsize = 11)
plt.legend()


plt.show()

# %%
# daily temperature

plt.figure(figsize = (20,4))

plt.plot(daily.Tagesdatum, daily["T"], "r.", label = "Temperature [°C]", lw = 0.3)

plt.title("Mean daily Temperature 2007 to 2021", fontsize = 16)
plt.ylabel("Temperature [°C]", fontsize = 11)
plt.xlabel("Years", fontsize = 11)
plt.legend()


plt.show()

# %% [markdown]
# ### DAILY: Vehicle and Weather data in 2021

# %%
# create dataframe with data from January 2021

daily_2021 = daily[daily.Jahr == 2021]

# %%
# Plot bicycles and Rain Duration daily 2021

fig, ax1 = plt.subplots(figsize = (12,8))

plt.title("Daily bicycles and Rain Duration 2021")
plt.xlabel("Months of 2021")

ax1.plot(daily_2021["Tagesdatum"], daily_2021["Zweirad"], "g.", label = "Bicycles", lw = 0.9)

ax2 = ax1.twinx()
ax2.plot(daily_2021["Tagesdatum"], daily_2021["RainDur"], "b.", lw = 0.9)

ax1.set_ylabel("Bicycle count")
ax2.set_ylabel("Rain Duration")

plt.show()

# %%
# Plot bicycles and Temperature daily 2021

fig, ax1 = plt.subplots(figsize = (12,8))

plt.title("Daily bicycles and Temperature 2021")
plt.xlabel("Months of 2021")

ax1.plot(daily_2021["Tagesdatum"], daily_2021["Zweirad"], "g.", label = "Bicycles", lw = 0.9)

ax2 = ax1.twinx()
ax2.plot(daily_2021["Tagesdatum"], daily_2021["T"], "r.", lw = 0.9)

ax1.set_ylabel("Bicycle count")
ax2.set_ylabel("Temperature")

plt.show()

# %%
# Plot bicycles and Global Radiation daily 2021

fig, ax1 = plt.subplots(figsize = (12,8))

plt.title("Daily bicycles and Global Radiation 2021")
plt.xlabel("Months of 2021")

ax1.plot(daily_2021["Tagesdatum"], daily_2021["Zweirad"], "g.", label = "Bicycles", lw = 0.9)

ax2 = ax1.twinx()
ax2.plot(daily_2021["Tagesdatum"], daily_2021["StrGlo"], "y.", lw = 0.9)

ax1.set_ylabel("Bicycle count")
ax2.set_ylabel("Global Radiation")

plt.show()

# %%
# Plot bicycles and Relative Humidity daily 2021

fig, ax1 = plt.subplots(figsize = (12,8))

plt.title("Daily bicycles and Relative Humidity 2021")
plt.xlabel("Months of 2021")

ax1.plot(daily_2021["Tagesdatum"], daily_2021["Zweirad"], "g.", label = "Bicycles", lw = 0.9)

ax2 = ax1.twinx()
ax2.plot(daily_2021["Tagesdatum"], daily_2021["Hr"], "b.", lw = 0.9)

ax1.set_ylabel("Bicycle count")
ax2.set_ylabel("Relative Humidity")

plt.show()

# %%
# Plot bicycles and Relative O3 2021

fig, ax1 = plt.subplots(figsize = (12,8))

plt.title("Daily bicycles and O3 2021")
plt.xlabel("Months of 2021")

ax1.plot(daily_2021["Tagesdatum"], daily_2021["Zweirad"], "g.", label = "Bicycles", lw = 0.7)

ax2 = ax1.twinx()
ax2.plot(daily_2021["Tagesdatum"], daily_2021["O3"], "b.", lw = 0.7)

ax1.set_ylabel("Bicycle count")
ax2.set_ylabel("O3")

plt.show()

# %% [markdown]
# ### DAILY: Vehicles relationship in 2021

# %%
# Plot bicycles and Trucks daily 2021

fig, ax1 = plt.subplots(figsize = (12,8))

plt.title("Daily bicycles and Trucks 2021")
plt.xlabel("Months of 2021")

ax1.plot(daily_2021["Tagesdatum"], daily_2021["Zweirad"], "g.", label = "Bicycles", lw = 0.7)

ax2 = ax1.twinx()
ax2.plot(daily_2021["Tagesdatum"], daily_2021["Lastwagen"], "r.", lw = 0.7)

ax1.set_ylabel("Bicycle count")
ax2.set_ylabel("Trucks count")

plt.show()

# %%
# Plot bicycles and Cars daily 2021

fig, ax1 = plt.subplots(figsize = (12,8))

plt.title("Daily bicycles and Cars 2021")
plt.xlabel("Months of 2021")

ax1.plot(daily_2021["Tagesdatum"], daily_2021["Zweirad"], "g.", label = "Bicycles", lw = 0.7)

ax2 = ax1.twinx()
ax2.plot(daily_2021["Tagesdatum"], daily_2021["Personenwagen"], "b.", lw = 0.7)

ax1.set_ylabel("Bicycle count")
ax2.set_ylabel("Cars count")

plt.show()

# %% [markdown]
# # Dataframe: Yearly means

# %%
# read data (yearly means)

yearly = pd.read_table('/Users/alisha/Documents/UZH_FS2022/ESC403_IDS/IDS_Project/data_science_project/processed_data/yearly_means.csv', sep = ";")

yearly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Jahr           15 non-null     int64
#  1   Zweirad        15 non-null     float64
#  2   Personenwagen  15 non-null     float64
#  3   Lastwagen      15 non-null     float64
#  4   Hr             15 non-null     float64
#  5   RainDur        15 non-null     float64
#  6   T              15 non-null     float64
#  7   WVs            15 non-null     float64
#  8   StrGlo         15 non-null     float64
#  9   p              15 non-null     float64
#  10  NO2            15 non-null     float64
#  11  NO             15 non-null     float64
#  12  NOx            15 non-null     float64
#  13  O3             15 non-null     float64
#  14  CO             15 non-null     float64
#  15  PM10           15 non-null     float64
#  16  SO2            15 non-null     float64
# dtypes: float64(16), int64(1)
# memory usage: 2.1 KB

# %% [markdown]
# Comment: This dataset contains the daily means for the samples from every year (2007-2021). There is one value per sample and year, which shows the daily average (not the count of the years).

# %% [markdown]
# ### YEARLY: Vehicles over the years

# %%
# daily mean vehicles for the years

plt.figure(figsize = (10,8))

plt.plot(yearly.Jahr, yearly.Personenwagen, "b.-", label = "cars", lw = 0.8)
plt.plot(yearly.Jahr, yearly.Lastwagen, "r.-", label = "trucks", lw = 0.8)
plt.plot(yearly.Jahr, yearly.Zweirad, "g.-", label = "bicycle", lw = 0.8)


plt.title("Mean daily vehicle counts for the years 2007 to 2021", fontsize = 18)
plt.ylabel("Vehicle counts", fontsize = 15)
plt.xlabel("Years", fontsize = 15)
plt.legend()


plt.show()

# %%
# daily mean car counts for the years

plt.figure(figsize = (10,5))

plt.plot(yearly.Jahr, yearly.Personenwagen, "b.-", label = "cars", lw = 0.8)

plt.title("Mean daily vehicle counts for the years 2007 to 2021", fontsize = 18)
plt.ylabel("Vehicle counts", fontsize = 15)
plt.xlabel("Years", fontsize = 15)
plt.legend()


plt.show()

# %%
# daily mean vehicles for the years

plt.figure(figsize = (10,5))

plt.plot(yearly.Jahr, yearly.Lastwagen, "r.-", label = "trucks", lw = 0.8)
plt.plot(yearly.Jahr, yearly.Zweirad, "g.-", label = "bicycle", lw = 0.8)

plt.title("Mean daily vehicle counts for the years 2007 to 2021", fontsize = 18)
plt.ylabel("Vehicle counts", fontsize = 15)
plt.xlabel("Years", fontsize = 15)
plt.legend()


plt.show()

# %% [markdown]
# ### YEARLY: Airquality data counts

# %%
# airquality data over the years
# x axis years (or mean of years)


plt.figure(figsize = (17,10))

plt.plot(yearly["Jahr"], yearly["NO2"], "m.-", label = "N02")
plt.plot(yearly["Jahr"], yearly["PM10"], "y.-", label = "PM10")
plt.plot(yearly["Jahr"], yearly["NO"], "g.-", label = "NO")
plt.plot(yearly["Jahr"], yearly["O3"], "c.-", label = "O3")
plt.plot(yearly["Jahr"], yearly["SO2"], "r.-", label = "SO2")


plt.title("Average daily airquality parameter values 2007 to 2021", fontsize = 22)
plt.ylabel("Values [µg/m³]", fontsize = 16)
plt.xlabel("Years", fontsize = 16)
plt.legend(fontsize = 16, loc = "upper left")


plt.show()

# %% [markdown]
# ### YEARLY: Weather data

# %%
# yearly rain duration

plt.figure(figsize = (10,5))

plt.plot(yearly.Jahr, yearly.RainDur, "b.-", label = "Rain Duration", lw = 0.8)

plt.title("Mean daily Rain Duration for the years 2007 to 2021", fontsize = 16)
plt.ylabel("Rain Duration [?]", fontsize = 11)
plt.xlabel("Years", fontsize = 11)
plt.legend()


plt.show()

# %%
# yearly relative humidity

plt.figure(figsize = (10,5))

plt.plot(yearly.Jahr, yearly.Hr, "b.-", label = "Relative Humidity", lw = 0.8)

plt.title("Mean daily Relative Humidity for the years 2007 to 2021", fontsize = 16)
plt.ylabel("Relative Humidity", fontsize = 11)
plt.xlabel("Years", fontsize = 11)
plt.legend()


plt.show()

# %% [markdown]
# ## Relationships between samples

# %% [markdown]
# ### RELATIONSHIP: Vehicles

# %%
# Plot Cars with Trucks

plt.style.use("seaborn")

plt.figure(figsize = (8,5))

plt.scatter(daily["Personenwagen"], daily["Lastwagen"], s = 6)

plt.title("Scatterplot: Cars and Trucks", fontsize = 16)
plt.ylabel("Trucks")
plt.xlabel("Cars")

plt.show()

# %%
# Plot Cars with Bicycles

plt.style.use("seaborn")

plt.figure(figsize = (8,5))

plt.scatter(daily["Personenwagen"], daily["Zweirad"], s = 6)

plt.title("Scatterplot: Cars and Bicycles", fontsize = 16)
plt.ylabel("Bicycles")
plt.xlabel("Cars")

plt.show()

# %%
# Plot Cars with Bicycles

plt.style.use("seaborn")

plt.figure(figsize = (8,5))

plt.scatter(daily["Lastwagen"], daily["Zweirad"], s = 6)

plt.title("Scatterplot: Trucks and Bicycles", fontsize = 16)
plt.xlabel("Trucks")
plt.ylabel("Bicycles")

plt.show()

# %%
# Plot Cars with Trucks Yearly

plt.style.use("seaborn")

plt.figure(figsize = (9,5))

plt.scatter(yearly["Personenwagen"], yearly["Lastwagen"], color = "orange", s = 40)

plt.title("Scatterplot: Cars and Trucks", fontsize = 16)
plt.ylabel("Trucks")
plt.xlabel("Cars")

plt.show()

# %%
# Plot Cars with Bicycles Yearly

plt.style.use("seaborn")

plt.figure(figsize = (9,5))

plt.scatter(yearly["Personenwagen"], yearly["Zweirad"], s = 30)

plt.title("Scatterplot: Cars and bicycles", fontsize = 16)
plt.ylabel("Bicycles")
plt.xlabel("Cars")

plt.show()

# %%
# Plot Trucks with Bicycles Yearly

plt.style.use("seaborn")

plt.figure(figsize = (9,5))

plt.scatter(yearly["Lastwagen"], yearly["Zweirad"], s = 30)

plt.title("Scatterplot: Cars and bicycles", fontsize = 16)
plt.ylabel("Bicycles")
plt.xlabel("Trucks")

plt.show()

# %%
 # Plot Cars with Bicycles

plt.style.use("seaborn")

plt.figure(figsize = (12,5))

plt.scatter(df_2021["Personenwagen"], df_2021["Zweirad"], s = 6)

plt.title("Scatterplot: Cars and bicycles", fontsize = 16)
plt.ylabel("Bicycles")
plt.xlabel("Cars")

plt.show()

# %% [markdown]
# ### RELATIONSHIP: Vehicles and Airquality data

# %%
# Plot Cars with Airquality data

plt.style.use("seaborn")

plt.figure(figsize = (12,5))

plt.scatter(daily["Personenwagen"], daily["NO2"], s = 6)

plt.title("Scatterplot: Cars and NO2", fontsize = 16)
plt.ylabel("NO2 [µg/m³]")
plt.xlabel("Cars")

plt.show()

# %%
# Plot Cars with Airquality data

plt.style.use("seaborn")

plt.figure(figsize = (12,5))

plt.scatter(daily["Personenwagen"], daily["PM10"], s = 6)

plt.title("Scatterplot: Cars and PM10", fontsize = 16)
plt.ylabel("PM10 [µg/m³]")
plt.xlabel("Cars")

plt.show()

# %%
# Plot Trucks with Airquality data

plt.style.use("seaborn")

plt.figure(figsize = (12,5))

plt.scatter(daily["Lastwagen"], daily["NO2"], s = 6)

plt.title("Scatterplot: Trucks and NO2", fontsize = 16)
plt.ylabel("NO2 [µg/m³]")
plt.xlabel("Trucks")

plt.show()

# %%
# Plot Trucks with Airquality data

plt.style.use("seaborn")

plt.figure(figsize = (12,5))

plt.scatter(daily["Lastwagen"], daily["PM10"], s = 6)

plt.title("Scatterplot: Trucks and PM10", fontsize = 16)
plt.ylabel("PM10 [µg/m³]")
plt.xlabel("Trucks")

plt.show()

# %%
# Plot Bicycle with Airquality data

plt.style.use("seaborn")

plt.figure(figsize = (12,5))

plt.scatter(daily["Zweirad"], daily["NO2"], s = 6)

plt.title("Scatterplot: Bicycle and NO2", fontsize = 16)
plt.ylabel("NO2 [µg/m³]")
plt.xlabel("Bicycle")

plt.show()

# %%
# Plot Bicycle with Airquality data

plt.style.use("seaborn")

plt.figure(figsize = (12,5))

plt.scatter(daily["Zweirad"], daily["PM10"], s = 6)

plt.title("Scatterplot: Bicycle and PM10", fontsize = 16)
plt.ylabel("PM10 [µg/m³]")
plt.xlabel("Bicycle")

plt.show()

# %%
# Plot Bicycle with weather data

plt.style.use("seaborn")

plt.figure(figsize = (12,5))

plt.scatter(daily["Zweirad"], daily["StrGlo"], s = 6)

plt.title("Scatterplot: Bicycle and Global Radiation", fontsize = 16)
plt.ylabel("Global Radiation")
plt.xlabel("Bicycle")

plt.show()

# %%
# Plot Bicycle with weather data

plt.style.use("seaborn")

plt.figure(figsize = (12,5))

plt.scatter(daily["Zweirad"], daily["RainDur"], s = 6)

plt.title("Scatterplot: Bicycle and Rain Duration", fontsize = 16)
plt.ylabel("Rain Duration []")
plt.xlabel("Bicycles")

plt.show()

# %%
# Plot Bicycle with weather data

plt.style.use("seaborn")

plt.figure(figsize = (12,5))

plt.scatter(daily["Zweirad"], daily["T"], s = 6)

plt.title("Scatterplot: Bicycles and Temperature", fontsize = 16)
plt.ylabel("Temperature [°C]")
plt.xlabel("Bicycles")

plt.show()

# %%
# Plot Bicycle with weather data

plt.style.use("seaborn")

plt.figure(figsize = (12,5))

plt.scatter(daily["Zweirad"], daily["WVs"], s = 6)

plt.title("Scatterplot: Bicycle and scalar Wind Velocity", fontsize = 16)
plt.ylabel("Scalar Wind Velocity []")
plt.xlabel("Bicycles")

plt.show()

# %%
# Correlation Plot (with EAQI)

import seaborn as sns
df = df.dropna()
df = df[['Zweirad','Personenwagen','Lastwagen','Hr','RainDur','T','WVs','StrGlo','p','AQI']]
df.rename(columns = {'Zweirad':'Bicyle', 'Personenwagen':'Cars','Lastwagen':'Trucks','Hr':'Rel.Humidity','T':'Temp','p':'Pressure','AQI':'EAQI'}, inplace = True)
plt.figure(figsize = (20,10))
sns.color_palette("mako", as_cmap=True)
sns.set(font_scale = 1.5)
correlation_plot = sns.heatmap(df.corr(), annot=True, linewidth=7,cmap="Blues")
